# %%
from sklearn.datasets import make_moons
X,y  = make_moons(n_samples=1000000000,noise=0.02)

# %%
import matplotlib.pyplot as plt
plt.scatter(X[:,0],X[:,1])

# %%
X
# Out:
# array([[-1.0265    ,  0.04233127],
#        [ 0.78646603,  0.62684713],
#        [ 1.69898373, -0.24253651],
#        ...,
#        [-0.0174878 ,  0.35272477],
#        [ 0.24181014, -0.1250973 ],
#        [ 0.98529084, -0.5353882 ]])

# %%
from sklearn.preprocessing import StandardScaler
scalar = StandardScaler()
X= scalar.fit_transform(X)

# %%
plt.scatter(X[:,0],X[:,1],c = y)

# %%
from sklearn.cluster import DBSCAN
scan = DBSCAN()
scan.fit(X)
# Out:
# DBSCAN()

# %%
plt.scatter(X[:,0],X[:,1],c = scan.labels_)

# %%
### try another hierarchikal
from sklearn.cluster import AgglomerativeClustering
cluster1 = AgglomerativeClustering(n_clusters=2,linkage='ward')
cluster1.fit(X)
# Out:
# AgglomerativeClustering()

# %%
plt.scatter(X[:,0],X[:,1],c = cluster1.labels_)
