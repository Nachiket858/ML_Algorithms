# %%
from sklearn.datasets import make_moons
X,y  = make_moons(n_samples=100,noise=0.02)

# %%
import matplotlib.pyplot as plt
plt.scatter(X[:,0],X[:,1])

# %%
X
# Out:
# array([[-1.00492263e+00,  7.98075803e-02],
#        [ 1.96159293e+00,  1.84341712e-01],
#        [ 7.68626234e-02,  1.95334339e-01],
#        [ 1.34382580e+00, -4.28429518e-01],
#        [-7.95777143e-01,  5.61244452e-01],
#        [ 7.69145980e-01, -4.66284396e-01],
#        [ 3.38304046e-01, -2.51787041e-01],
#        [ 1.03441890e+00, -4.89918779e-01],
#        [ 2.62383445e-01, -1.20447728e-01],
#        [ 4.39109349e-01, -3.51659313e-01],
#        [ 1.60991883e+00, -2.83488723e-01],
#        [ 5.11900505e-01,  8.80883511e-01],
#        [ 1.57489970e+00, -3.36511360e-01],
#        [ 4.57190302e-01,  8.86467392e-01],
#        [ 1.17837857e+00, -5.04225338e-01],
#        [ 6.84351166e-01, -4.65024362e-01],
#        [ 1.06920860e+00, -4.90489453e-01],
#        [ 9.12830340e-01, -4.69117411e-01],
#        [-7.25020990e-03,  1.01125042e+00],
#        [ 1.91816613e+00, -3.61305050e-02],
#        [ 7.09876181e-01,  7.18968052e-01],
#        [ 1.47992755e+00, -3.43418834e-01],
#        [-3.78845514e-01,  9.27787699e-01],
#        [-8.93901336e-01,  4.90376728e-01],
#        [ 2.02655581e+00,  3.76371168e-01],
#        [ 9.50081437e-01,  2.02400465e-01],
#        [-5.81051225e-01,  8.44289322e-01],
#        [ 9.35244707e-01, -5.09606428e-01],
#        [ 2.01656342e-01, -9.74680932e-02],
#        [ 8.74012446e-01,  4.74015558e-01],
#        [-2.74388006e-01,  9.10255487e-01],
#        [-9.43031863e-01,  3.68080892e-01],
#        [ 5.62052667e-01,  8.31862638e-01],
#        [ 1.01647803e+00, -7.59735365e-03],
#        [-9.68847554e-01,  2.75364656e-01],
#        [-7.15338211e-01,  6.99015164e-01],
#        [ 1.58491395e-02,  3.72464954e-01],
#        [ 9.91219380e-01,  7.45168828e-02],
#        [ 1.43829200e+00, -4.25637395e-01],
#        [ 5.12598230e-01, -4.07785323e-01],
#        [ 2.75582946e-01,  9.68326977e-01],
#        [ 3.75410919e-01, -3.05965436e-01],
#        [ 1.69031520e+00, -2.08730940e-01],
#        [-4.45562497e-01,  9.15473069e-01],
#        [-9.89517430e-01,  2.96927839e-01],
#        [-1.31870308e-01,  9.85837890e-01],
#        [-8.45590968e-01,  5.33387496e-01],
#        [ 1.83953616e+00, -4.51758603e-02],
#        [ 9.35771422e-01,  3.39666879e-01],
#        [ 1.74501911e+00, -1.32156662e-01],
#        [-5.02580190e-01,  8.68491146e-01],
#        [ 8.67755372e-01, -4.60885482e-01],
#        [ 1.67357629e+00, -2.67901063e-01],
#        [ 8.02198153e-01,  6.03186525e-01],
#        [ 4.10261356e-03,  4.46031899e-01],
#        [ 1.98033041e+00,  4.95896796e-01],
#        [-2.22847356e-01,  9.52606106e-01],
#        [ 1.91842149e+00,  1.24424980e-01],
#        [ 1.94921146e+00,  2.99489013e-01],
#        [ 1.19582172e-02,  2.12702298e-01],
#        [ 6.09138512e-01,  7.70580760e-01],
#        [ 4.58335561e-01, -3.43304272e-01],
#        [ 6.05095032e-01, -4.22149998e-01],
#        [ 9.40316724e-01,  3.81932319e-01],
#        [ 9.13521863e-02,  9.90852972e-01],
#        [-7.10176225e-05,  5.19154747e-01],
#        [ 1.79416428e+00, -9.89220750e-02],
#        [-3.63712572e-01,  9.30332707e-01],
#        [-7.14691921e-01,  7.67173213e-01],
#        [ 1.29600350e+00, -4.64050710e-01],
#        [ 1.99957063e+00,  4.11935059e-01],
#        [ 3.01362781e-01, -2.02919665e-01],
#        [ 7.58158667e-01,  6.15900495e-01],
#        [-5.71417462e-02,  9.64107223e-01],
#        [-9.97225676e-01,  1.38019136e-02],
#        [ 6.33941621e-01, -4.46720623e-01],
#        [ 1.08943981e-02,  2.55385329e-01],
#        [ 4.00649029e-01,  9.46141103e-01],
#        [ 1.96379001e+00,  3.32262710e-01],
#        [ 1.56407742e+00, -3.19320446e-01],
#        [ 8.71894031e-01,  4.42221779e-01],
#        [ 1.20516285e+00, -4.71078167e-01],
#        [ 1.94383195e-02,  9.87719085e-01],
#        [ 9.02715848e-02,  8.23358377e-02],
#        [ 1.89605486e+00,  9.39451357e-02],
#        [ 8.48683569e-01,  5.52899765e-01],
#        [ 1.06118625e-01,  8.79351322e-02],
#        [ 2.15673016e-01,  9.69468713e-01],
#        [-8.81412964e-01,  4.77656130e-01],
#        [ 9.44363695e-02,  4.95398514e-02],
#        [ 1.79634050e-01, -4.60687729e-02],
#        [-7.77925639e-01,  6.58220284e-01],
#        [ 6.67268105e-01,  7.78490197e-01],
#        [ 9.72297445e-01,  2.76920758e-01],
#        [ 3.92974766e-01,  9.14314460e-01],
#        [-9.94732039e-01,  2.13055139e-01],
#        [-9.99798729e-01,  1.23488846e-01],
#        [-6.59844436e-01,  7.88170828e-01],
#        [ 1.00177623e+00,  1.45857670e-01],
#        [ 1.48807788e-01,  9.86588623e-01]])

# %%
from sklearn.preprocessing import StandardScaler
scalar = StandardScaler()
X= scalar.fit_transform(X)

# %%
plt.scatter(X[:,0],X[:,1],c = y)

# %%
from sklearn.cluster import DBSCAN
scan = DBSCAN()
scan.fit(X)
# Out:
# DBSCAN()

# %%
plt.scatter(X[:,0],X[:,1],c = scan.labels_)

# %%
### try another hierarchikal
from sklearn.cluster import AgglomerativeClustering
cluster1 = AgglomerativeClustering(n_clusters=2,linkage='ward')
cluster1.fit(X)
# Out:
# AgglomerativeClustering()

# %%
plt.scatter(X[:,0],X[:,1],c = cluster1.labels_)
